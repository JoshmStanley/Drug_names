# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshmStanley/Drug_names/blob/main/Beating_bert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
# !pip install datasets

# %%
import pandas as pd
#importing the transformers package
import transformers
#importing huggingface pipeline 
from transformers import pipeline, AutoTokenizer, AutoModel, AutoModelForTokenClassification, TrainingArguments
#importing tokenizers
import torch
from datasets import load_dataset

# %%
#from google.colab import files

#uploaded = files.upload()

# %%
dataset = load_dataset("ghadeermobasher/BC5CDR-Chemical-Disease")

# %%
#tokenizer for biobert model. The model requires pytorch tensors and not a python list so had to add add return_tensors='pt' as an argument

bert_checkpoint = "emilyalsentzer/Bio_ClinicalBERT"

tokenizer = AutoTokenizer.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
model = AutoModel.from_pretrained(bert_checkpoint)

# %%
#need to re-tokenize the data first
dataset["train"].features[f"ner_tags"]
label_list = dataset["train"].features[f"ner_tags"].feature.names

# %%
dataset

# %%
training_tokens = tokenizer(dataset['train']["tokens"], is_split_into_words=True)
training_ids = tokenizer.convert_ids_to_tokens(dataset['train']['id'])
test_tokens = tokenizer(dataset['test']["tokens"], is_split_into_words=True)
test_ids = tokenizer.convert_ids_to_tokens(dataset['test']['id'])

# %%
training_ids
#something seems wrong with the training_ids^

# %% [markdown]
# this is the BC4CHEMD NER dataset that we will be using to re-train our models
#
# training_dataset = load_dataset("drAbreu/bc4chemd_ner", split='train')
# test_dataset = load_dataset("drAbreu/bc4chemd_ner", split='test')
# validation_dataset = load_dataset("drAbreu/bc4chemd_ner", split='validation')
